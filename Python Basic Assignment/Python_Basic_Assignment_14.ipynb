# %% [markdown]
# ### 1. What does RGBA stand for?

# %% [markdown]
# An RGB color value represents RED, GREEN, and BLUE light sources. An RGBA color value is an extension of RGB with an Alpha channel (opacity).

# %% [markdown]
# ### 2. From the Pillow module, how do you get the RGBA value of any images?

# %% [markdown]
# getdata() method will give us a sequence of (red, green, blue, alpha) tuples pretty quickly.

# %%
from PIL import Image
img = Image.open('cat.jpg')
pixels = img.convert('RGBA')
rgba_data = pixels.getdata()
for i in rgba_data:
    print(i)

# %% [markdown]
# ### 3. What is a box tuple, and how does it work?

# %% [markdown]
# Many of Pillow’s functions and methods take a box tuple argument. This means Pillow is expecting a tuple of four integer coordinates that represent a rectangular region in an image. The four integers are, in order, as follows:
# - __Left__ The x-coordinate of the leftmost edge of the box.
# - __Top__ The y-coordinate of the top edge of the box.
# - __Right__ The x-coordinate of one pixel to the right of the rightmost edge of the box. This integer must be greater than the left integer.
# - __Bottom__ The y-coordinate of one pixel lower than the bottom edge of the box. This integer must be greater than the top integer.<br>
#
# Below is the example of box tuple (3, 1, 9, 6)

# %% [markdown]
# ![box%20tuple.jpg](attachment:box%20tuple.jpg)

# %% [markdown]
# ### 4. Use your image and load in notebook then, How can you find out the width and height of an Image object?

# %%
from PIL import Image
img = Image.open('cat.jpg')
print(f"Width and height of an image are {img.width}, {img.height} respectively")
# Out:
# Width and height of an image are 4000, 6000 respectively

# %% [markdown]
# ### 5. What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?

# %% [markdown]
# we can use __Image.crop((0,50,50,50))__ to get image excluding the lower-left quarter of it.

# %% [markdown]
# ### 6. After making changes to an Image object, how could you save it as an image file?

# %%
from PIL import Image
img = Image.open('cat.jpg')
img.save('cat1.jpg')

# %% [markdown]
# ### 7. What module contains Pillow’s shape-drawing code?

# %% [markdown]
# __ImageDraw__ module contains Pillow’s shape-drawing code.

# %% [markdown]
# ### 8. Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?

# %% [markdown]
# We shape drawing methods like __line(), point(), rectangle()__ and we can call them by using __ImageDraw.Draw()__ function.
